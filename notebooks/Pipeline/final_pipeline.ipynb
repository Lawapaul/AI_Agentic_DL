# %%
# Setup
import importlib
import os
import subprocess
import sys
from pathlib import Path

IS_COLAB = 'google.colab' in sys.modules
REPO_PATH = Path('/content/AI_Agentic_DL') if IS_COLAB else Path.cwd()
TARGET_BRANCH = 'final-pipeline-integration'
REQUIRED_DATA_FILES = ['X_train.npy', 'X_test.npy', 'y_train.npy', 'y_test.npy']
ENV_MARKER = '/tmp/final_pipeline_env_ready_v4'

if IS_COLAB and not REPO_PATH.exists():
    # !git clone https://github.com/Lawapaul/AI_Agentic_DL.git /content/AI_Agentic_DL

if str(REPO_PATH) not in sys.path:
    sys.path.insert(0, str(REPO_PATH))

subprocess.check_call(['git', '-C', str(REPO_PATH), 'fetch', 'origin'])
subprocess.check_call(['git', '-C', str(REPO_PATH), 'checkout', TARGET_BRANCH])
subprocess.check_call(['git', '-C', str(REPO_PATH), 'pull', 'origin', TARGET_BRANCH])

def ensure_package(requirement, import_name=None):
    import_name = import_name or requirement.split('==')[0].split('>=')[0].replace('-', '_')
    try:
        importlib.import_module(import_name)
        return False
    except Exception:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', requirement])
        return True

def tensorflow_healthy():
    try:
        subprocess.check_call([
            sys.executable, '-c',
            'import tensorflow as tf; import tensorflow.python; print(tf.__version__)'
        ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        return True
    except Exception:
        return False

changed = False
if not os.path.exists(ENV_MARKER):
    changed |= ensure_package('lime>=0.2.0.1', 'lime')
    changed |= ensure_package('transformers==4.41.2', 'transformers')
    changed |= ensure_package('accelerate==0.30.1', 'accelerate')
    changed |= ensure_package('sentencepiece>=0.1.99', 'sentencepiece')
    changed |= ensure_package('networkx>=3.0.0', 'networkx')
    changed |= ensure_package('pyarrow>=15.0.0', 'pyarrow')

if not tensorflow_healthy():
    subprocess.check_call([sys.executable, '-m', 'pip', 'uninstall', '-y', 'tensorflow', 'tensorflow-cpu', 'tf-keras', 'keras', 'ml-dtypes', 'jax', 'jaxlib'])
    subprocess.check_call([
        sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', '--force-reinstall',
        'numpy==1.26.4',
        'ml-dtypes==0.3.2',
        'tensorflow==2.16.1',
        'keras==3.3.3',
    ])
    changed = True

Path(ENV_MARKER).write_text('ready', encoding='utf-8')
if changed:
    raise SystemExit('Environment updated. Restart runtime once, then rerun this cell.')

for module_name in list(sys.modules):
    if module_name.startswith(('transformers', 'accelerate', 'tokenizers', 'huggingface_hub', 'tensorflow', 'keras', 'jax')):
        del sys.modules[module_name]

if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)

DEFAULT_PROCESSED_PATHS = [
    '/content/drive/MyDrive/Deep Learning Project/AI Agentic/data/processed',
    '/content/drive/MyDrive/AI Agentic/data/processed',
    '/content/AI_Agentic_DL/data/processed',
    str(REPO_PATH / 'data' / 'processed'),
]
DEFAULT_MODEL_PATHS = [
    '/content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras',
    '/content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/ids_model.keras',
    '/content/drive/MyDrive/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras',
    '/content/AI_Agentic_DL/saved_models/ids_model.keras',
    str(REPO_PATH / 'saved_models' / 'ids_model.keras'),
]

def first_existing_processed(paths):
    for path in paths:
        path_obj = Path(path)
        if path_obj.exists() and all((path_obj / name).exists() for name in REQUIRED_DATA_FILES):
            return str(path_obj)
    return None

def first_existing_file(paths):
    for path in paths:
        if Path(path).exists():
            return path
    return None

PROCESSED_PATH = first_existing_processed(DEFAULT_PROCESSED_PATHS)
MODEL_PATH = first_existing_file(DEFAULT_MODEL_PATHS)

if PROCESSED_PATH is None:
    raise FileNotFoundError('Could not find processed dataset files. Checked: ' + ', '.join(DEFAULT_PROCESSED_PATHS))

if MODEL_PATH is None:
    raise FileNotFoundError('Could not find a trained hybrid model. Checked: ' + ', '.join(DEFAULT_MODEL_PATHS))

print('Repo branch:', TARGET_BRANCH)
print('Processed path:', PROCESSED_PATH)
print('Model path:', MODEL_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo branch: final-pipeline-integration
# Processed path: /content/drive/MyDrive/Deep Learning Project/AI Agentic/data/processed
# Model path: /content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras

# %%
# Load modules
import importlib
import sys

importlib.invalidate_caches()
if 'integration.final_pipeline' in sys.modules:
    del sys.modules['integration.final_pipeline']

import integration.final_pipeline as final_pipeline
final_pipeline = importlib.reload(final_pipeline)
run_demo_pipeline = final_pipeline.run_demo_pipeline
run_full_pipeline = final_pipeline.run_full_pipeline

# %%
# Run full pipeline (safe mode)
full_summary = run_full_pipeline(PROCESSED_PATH, MODEL_PATH)
print(full_summary['status'])
print(full_summary['runtime'])
print(full_summary['decision_planner'])
print(full_summary['retraining'])
# Out:
# INFO:integration.final_pipeline:Starting final pipeline with runtime={'available_ram_gb': 10.4, 'max_samples': 50, 'batch_size': 64, 'device': 'CPU', 'demo_mode': False, 'platform': 'Linux-6.6.113+-x86_64-with-glibc2.35'}
# Loading model from: /content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras
#
# === Initializing Feature Gradient Explainer ===
# Number of features: 78
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# completed
# {'available_ram_gb': 10.4, 'max_samples': 50, 'batch_size': 64, 'device': 'CPU', 'demo_mode': False, 'platform': 'Linux-6.6.113+-x86_64-with-glibc2.35'}
# {'best_planner': 'policy', 'metrics': {'rule_based': {'accuracy': 0.6, 'consistency': 1.0, 'reward': 0.23538, 'majority_action': 'Block'}, 'confidence_based': {'accuracy': 0.04, 'consistency': 1.0, 'reward': -1.04058, 'majority_action': 'No Action'}, 'risk_based': {'accuracy': 0.04, 'consistency': 1.0, 'reward': -1.04058, 'majority_action': 'No Action'}, 'hybrid': {'accuracy': 0.06, 'consistency': 1.0, 'reward': -0.99682, 'majority_action': 'No Action'}, 'rl': {'accuracy': 0.62, 'consistency': 1.0, 'reward': 0.28054, 'majority_action': 'Block'}, 'policy': {'accuracy': 0.84, 'consistency': 1.0, 'reward': 0.7664200000000001, 'majority_action': 'Block'}, 'llm': {'accuracy': 0.0, 'consistency': 1.0, 'reward': -1.1288600000000002, 'majority_action': 'No Action'}}}
# {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7132132132132132, 'consistency': 1.0, 'reward': 0.4264264264264264}, 'supervised_trainer': {'accuracy': 0.7127127127127127, 'consistency': 1.0, 'reward': 0.42542542542542544, 'training_summary': {'epochs': 20, 'loss': 0.7777211666107178, 'samples': 1998}}}}

# %%
# Run demo pipeline (presentation mode)
demo_summary = run_demo_pipeline()
print('Demo samples:', len(demo_summary.get('records', [])))
# Out:
# INFO:integration.final_pipeline:Starting final pipeline with runtime={'available_ram_gb': 10.18, 'max_samples': 8, 'batch_size': 64, 'device': 'CPU', 'demo_mode': True, 'platform': 'Linux-6.6.113+-x86_64-with-glibc2.35'}
# Loading model from: /content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras
#
# === Initializing Feature Gradient Explainer ===
# Number of features: 78
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ---------------------------------
#  SAMPLE 1
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.999997079372406}
# Top Features: ['feature_70 (-0.0008)', 'feature_72 (-0.0007)', 'feature_40 (-0.0003)', 'feature_53 (-0.0003)', 'feature_1 (0.0003)', 'feature_7 (-0.0003)', 'feature_20 (0.0002)', 'feature_38 (0.0002)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_-1', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.5], 'top_similarity': 0.5}
# Fused Risk Score: {'risk_score': 0.6750014199533325, 'severity': 'HIGH'}
# LLM Reasoning: High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.
# Decision: {'event_id': 'sample_0', 'risk_score': 0.6750014199533325, 'uncertainty': 2.9206275939941406e-06, 'explanation': 'High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 1999, 'event_id': 'sample_0', 'state': '{"risk_score": 0.6750014199533325, "uncertainty": 2.9206275939941406e-06, "suggested_action": "Block", "explanation": "High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block."}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:29.513032+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7133566783391696, 'consistency': 1.0, 'reward': 0.42671335667833915}, 'supervised_trainer': {'accuracy': 0.7128564282141071, 'consistency': 1.0, 'reward': 0.4257128564282141, 'training_summary': {'epochs': 20, 'loss': 0.7278907895088196, 'samples': 1999}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 2
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.9999881386756897}
# Top Features: ['feature_70 (-0.0005)', 'feature_72 (-0.0005)', 'feature_52 (-0.0004)', 'feature_37 (-0.0003)', 'feature_8 (-0.0002)', 'feature_64 (-0.0002)', 'feature_0 (0.0002)', 'feature_47 (-0.0001)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_0', 'weight': 0.9995802044868469}], 'max_weight': 0.9995802044868469}
# Memory Match: {'labels': [0], 'similarities': [0.9995802640914917], 'top_similarity': 0.9995802640914917}
# Fused Risk Score: {'risk_score': 0.899817906471435, 'severity': 'CRITICAL'}
# LLM Reasoning: High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.
# Decision: {'event_id': 'sample_1', 'risk_score': 0.899817906471435, 'uncertainty': 1.1861324310302734e-05, 'explanation': 'High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.', 'suggested_action': 'Block'}
# Human Review: {'approved': False, 'correct_action': 'Block', 'feedback': 'Adjusted action to Block based on risk and uncertainty.', 'severity_adjustment': 0.0, 'reviewer_id': 'simulated-analyst', 'reviewed_at': datetime.datetime(2026, 3, 30, 10, 36, 30, 133428)}
# Feedback Stored: {'id': 2000, 'event_id': 'sample_1', 'state': '{"risk_score": 0.899817906471435, "uncertainty": 1.1861324310302734e-05, "suggested_action": "Block", "explanation": "High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block."}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:30.133505+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7135, 'consistency': 1.0, 'reward': 0.427}, 'supervised_trainer': {'accuracy': 0.713, 'consistency': 1.0, 'reward': 0.426, 'training_summary': {'epochs': 20, 'loss': 0.6325393915176392, 'samples': 2000}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 3
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.999998152256012}
# Top Features: ['feature_0 (0.0000)', 'feature_1 (0.0000)', 'feature_2 (0.0000)', 'feature_3 (0.0000)', 'feature_4 (0.0000)', 'feature_5 (0.0000)', 'feature_6 (0.0000)', 'feature_7 (0.0000)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_1', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.5], 'top_similarity': 0.5}
# Fused Risk Score: {'risk_score': 0.6750002726799721, 'severity': 'HIGH'}
# LLM Reasoning: Feature Summary: [2.644, -0.44, -0.01, -0.055, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -
# Decision: {'event_id': 'sample_2', 'risk_score': 0.6750002726799721, 'uncertainty': 1.8477439880371094e-06, 'explanation': 'Feature Summary: [2.644, -0.44, -0.01, -0.055, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 2001, 'event_id': 'sample_2', 'state': '{"risk_score": 0.6750002726799721, "uncertainty": 1.8477439880371094e-06, "suggested_action": "Block", "explanation": "Feature Summary: [2.644, -0.44, -0.01, -0.055, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -0.007, -"}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:30.745496+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7136431784107946, 'consistency': 1.0, 'reward': 0.4272863568215892}, 'supervised_trainer': {'accuracy': 0.7131434282858571, 'consistency': 1.0, 'reward': 0.42628685657171417, 'training_summary': {'epochs': 20, 'loss': 0.6894713044166565, 'samples': 2001}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 4
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.9999991059303284}
# Top Features: ['feature_41 (-0.0002)', 'feature_8 (-0.0002)', 'feature_67 (-0.0002)', 'feature_53 (0.0001)', 'feature_63 (0.0001)', 'feature_4 (0.0001)', 'feature_9 (-0.0001)', 'feature_6 (-0.0000)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_2', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.5], 'top_similarity': 0.5}
# Fused Risk Score: {'risk_score': 0.6750000941184225, 'severity': 'HIGH'}
# LLM Reasoning: High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.
# Decision: {'event_id': 'sample_3', 'risk_score': 0.6750000941184225, 'uncertainty': 8.940696716308594e-07, 'explanation': 'High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 2002, 'event_id': 'sample_3', 'state': '{"risk_score": 0.6750000941184225, "uncertainty": 8.940696716308594e-07, "suggested_action": "Block", "explanation": "High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block."}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:31.365932+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7137862137862138, 'consistency': 1.0, 'reward': 0.4275724275724276}, 'supervised_trainer': {'accuracy': 0.7132867132867133, 'consistency': 1.0, 'reward': 0.42657342657342656, 'training_summary': {'epochs': 20, 'loss': 0.8655222654342651, 'samples': 2002}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 5
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.8474025130271912}
# Top Features: ['feature_72 (-0.0005)', 'feature_70 (-0.0005)', 'feature_35 (-0.0003)', 'feature_67 (-0.0003)', 'feature_66 (-0.0002)', 'feature_11 (-0.0002)', 'feature_38 (0.0002)', 'feature_53 (-0.0002)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_3', 'weight': 0.7305527925491333}], 'max_weight': 0.7305527925491333}
# Memory Match: {'labels': [0], 'similarities': [0.7305527925491333], 'top_similarity': 0.7305527925491333}
# Fused Risk Score: {'risk_score': 0.810079887509346, 'severity': 'CRITICAL'}
# LLM Reasoning: Feature Summary: [-0.037, -0.037, -0.008, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.0
# Decision: {'event_id': 'sample_4', 'risk_score': 0.810079887509346, 'uncertainty': 0.15259748697280884, 'explanation': 'Feature Summary: [-0.037, -0.037, -0.008, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.0', 'suggested_action': 'Block'}
# Human Review: {'approved': False, 'correct_action': 'Alert', 'feedback': 'Adjusted action to Alert based on risk and uncertainty.', 'severity_adjustment': 0.0, 'reviewer_id': 'simulated-analyst', 'reviewed_at': datetime.datetime(2026, 3, 30, 10, 36, 31, 971725)}
# Feedback Stored: {'id': 2003, 'event_id': 'sample_4', 'state': '{"risk_score": 0.810079887509346, "uncertainty": 0.15259748697280884, "suggested_action": "Block", "explanation": "Feature Summary: [-0.037, -0.037, -0.008, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.039, -0.0"}', 'action_taken': 'Block', 'human_action': 'Alert', 'reward': -1.0, 'timestamp': '2026-03-30T10:36:31.971797+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7134298552171743, 'consistency': 1.0, 'reward': 0.4268597104343485}, 'supervised_trainer': {'accuracy': 0.7129306040938592, 'consistency': 1.0, 'reward': 0.42586120818771844, 'training_summary': {'epochs': 20, 'loss': 0.6712430119514465, 'samples': 2003}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 6
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.9999995827674866}
# Top Features: ['feature_36 (-0.0000)', 'feature_14 (-0.0000)', 'feature_15 (-0.0000)', 'feature_7 (-0.0000)', 'feature_38 (-0.0000)', 'feature_51 (0.0000)', 'feature_69 (-0.0000)', 'feature_0 (-0.0000)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_4', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.6531117558479309], 'top_similarity': 0.6531117558479309}
# Fused Risk Score: {'risk_score': 0.7132779278140674, 'severity': 'HIGH'}
# LLM Reasoning: High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.
# Decision: {'event_id': 'sample_5', 'risk_score': 0.7132779278140674, 'uncertainty': 4.172325134277344e-07, 'explanation': 'High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 2004, 'event_id': 'sample_5', 'state': '{"risk_score": 0.7132779278140674, "uncertainty": 4.172325134277344e-07, "suggested_action": "Block", "explanation": "High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block."}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:32.523862+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7135728542914171, 'consistency': 1.0, 'reward': 0.42714570858283435}, 'supervised_trainer': {'accuracy': 0.7130738522954092, 'consistency': 1.0, 'reward': 0.42614770459081835, 'training_summary': {'epochs': 20, 'loss': 0.6310911178588867, 'samples': 2004}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 7
# ---------------------------------
# Classifier Output: {'prediction': 0, 'confidence': 0.9999551177024841}
# Top Features: ['feature_72 (-0.0007)', 'feature_39 (-0.0002)', 'feature_54 (-0.0001)', 'feature_5 (0.0001)', 'feature_52 (-0.0001)', 'feature_41 (-0.0001)', 'feature_12 (-0.0001)', 'feature_10 (0.0000)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_4', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.5], 'top_similarity': 0.5}
# Fused Risk Score: {'risk_score': 0.6750396813673434, 'severity': 'HIGH'}
# LLM Reasoning: High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.
# Decision: {'event_id': 'sample_6', 'risk_score': 0.6750396813673434, 'uncertainty': 4.488229751586914e-05, 'explanation': 'High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block.', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 2005, 'event_id': 'sample_6', 'state': '{"risk_score": 0.6750396813673434, "uncertainty": 4.488229751586914e-05, "suggested_action": "Block", "explanation": "High risk detected from correlated graph behavior, memory similarity, and the most important network features. Recommended action: Block."}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:33.131944+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7137157107231921, 'consistency': 1.0, 'reward': 0.427431421446384}, 'supervised_trainer': {'accuracy': 0.713216957605985, 'consistency': 1.0, 'reward': 0.42643391521197005, 'training_summary': {'epochs': 20, 'loss': 0.6905421614646912, 'samples': 2005}}}}
# ---------------------------------
# ---------------------------------
#  SAMPLE 8
# ---------------------------------
# Classifier Output: {'prediction': 2, 'confidence': 0.9998190402984619}
# Top Features: ['feature_70 (-0.0007)', 'feature_72 (-0.0006)', 'feature_67 (-0.0003)', 'feature_52 (-0.0002)', 'feature_0 (0.0002)', 'feature_47 (-0.0002)', 'feature_6 (-0.0001)', 'feature_51 (-0.0001)']
# Graph Correlation: {'top_neighbors': [{'sample_id': 'sample_4', 'weight': 0.5}], 'max_weight': 0.5}
# Memory Match: {'labels': [0], 'similarities': [0.6642962694168091], 'top_similarity': 0.6642962694168091}
# Fused Risk Score: {'risk_score': 0.7166092758998275, 'severity': 'HIGH'}
# LLM Reasoning: Answer: a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a)
# Decision: {'event_id': 'sample_7', 'risk_score': 0.7166092758998275, 'uncertainty': 0.00018095970153808594, 'explanation': 'Answer: a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a)', 'suggested_action': 'Block'}
# Human Review: {'approved': True, 'correct_action': 'Block', 'feedback': 'Auto-approved because risk and uncertainty stayed below review thresholds.', 'severity_adjustment': 0.0}
# Feedback Stored: {'id': 2006, 'event_id': 'sample_7', 'state': '{"risk_score": 0.7166092758998275, "uncertainty": 0.00018095970153808594, "suggested_action": "Block", "explanation": "Answer: a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a) a)"}', 'action_taken': 'Block', 'human_action': 'Block', 'reward': 1.0, 'timestamp': '2026-03-30T10:36:33.711460+00:00'}
# Retraining Update: {'best_method': 'rl_trainer', 'metrics': {'rl_trainer': {'accuracy': 0.7138584247258225, 'consistency': 1.0, 'reward': 0.42771684945164506}, 'supervised_trainer': {'accuracy': 0.7133599202392822, 'consistency': 1.0, 'reward': 0.4267198404785643, 'training_summary': {'epochs': 20, 'loss': 0.7220489382743835, 'samples': 2006}}}}
# ---------------------------------
# Demo samples: 8

# %%
# Plot pipeline results
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')

records = demo_summary.get('records', [])
plot_df = pd.DataFrame([
    {
        'sample_index': r.get('sample_index', i),
        'risk_score': r.get('fused_risk', {}).get('risk_score', 0.0),
        'severity': r.get('fused_risk', {}).get('severity', 'UNKNOWN'),
        'decision': r.get('decision', {}).get('suggested_action', 'Unknown'),
        'confidence': r.get('classifier_output', {}).get('confidence', 0.0),
    }
    for i, r in enumerate(records)
])

if not plot_df.empty:
    fig, axes = plt.subplots(1, 3, figsize=(18, 4.5))

    sns.barplot(data=plot_df, x='sample_index', y='risk_score', hue='severity', palette='viridis', ax=axes[0])
    axes[0].set_title('Demo Risk Score by Sample')
    axes[0].set_xlabel('Sample Index')
    axes[0].set_ylabel('Risk Score')
    axes[0].legend(title='Severity', loc='best')

    decision_counts = plot_df['decision'].value_counts().reset_index()
    decision_counts.columns = ['decision', 'count']
    sns.barplot(data=decision_counts, x='decision', y='count', palette='Set2', ax=axes[1])
    axes[1].set_title('Decision Distribution')
    axes[1].set_xlabel('Decision')
    axes[1].set_ylabel('Count')

    sns.lineplot(data=plot_df, x='sample_index', y='confidence', marker='o', ax=axes[2], color='#d55e00')
    axes[2].set_title('Classifier Confidence by Sample')
    axes[2].set_xlabel('Sample Index')
    axes[2].set_ylabel('Confidence')
    axes[2].set_ylim(0.0, 1.05)

    plt.tight_layout()
    plt.show()

    result_dir = demo_summary.get('drive_results_dir') or os.path.join('experiments', 'results', 'final_pipeline')
    os.makedirs(result_dir, exist_ok=True)
    figure_path = os.path.join(result_dir, 'demo_pipeline_graphs.png')
    fig.savefig(figure_path, dpi=200, bbox_inches='tight')
    print('Saved pipeline graphs:', figure_path)
else:
    print('No demo records available for plotting.')
# Out:
# /tmp/ipykernel_23831/585752417.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=decision_counts, x='decision', y='count', palette='Set2', ax=axes[1])
# Saved pipeline graphs: /content/drive/MyDrive/Deep Learning Project/AI Agentic/experiments/results/final_pipeline/demo_pipeline_graphs.png
