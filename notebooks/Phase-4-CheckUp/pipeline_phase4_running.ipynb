# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "/content/drive/MyDrive/Deep Learning Project/AI Agentic/data/processed"
print(os.listdir(path))
# Out:
# ['y_train.npy', 'X_train.npy', 'X_test.npy', 'y_test.npy']

# %%
# !git clone https://github.com/Lawapaul/AI_Agentic_DL.git
# %cd AI_Agentic_DL
# Out:
# Cloning into 'AI_Agentic_DL'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 311 (delta 31), reused 61 (delta 21), pack-reused 235 (from 1)
# Receiving objects: 100% (311/311), 191.35 KiB | 1.53 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# /content/AI_Agentic_DL

# %%
# !git branch
# !git checkout phase4-memory-retrieval
# Out:
# * main
# Branch 'phase4-memory-retrieval' set up to track remote branch 'phase4-memory-retrieval' from 'origin'.
# Switched to a new branch 'phase4-memory-retrieval'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.21 KiB | 621.00 KiB/s, done.
# From https://github.com/Lawapaul/AI_Agentic_DL
#    97b3c90..fc856b3  phase4-memory-retrieval -> origin/phase4-memory-retrieval
# Updating 97b3c90..fc856b3
# Fast-forward
#  experiments/phase4_memory_pipeline.py | 99 ++++++++++++++++++++++++++---------
#  1 file changed, 74 insertions(+), 25 deletions(-)

# %%
# !PYTHONPATH=/content/AI_Agentic_DL python experiments/phase4_memory_pipeline.py \
  --processed_path "/content/drive/MyDrive/Deep Learning Project/AI Agentic/data/processed" \
  --model_path "/content/drive/MyDrive/Deep Learning Project/AI Agentic/saved_models/hybrid_cnn_lstm_full_2_2m.keras" \
  --compare_all
# Out:
# 2026-02-28 10:13:08.398284: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772273588.420087   10408 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772273588.427148   10408 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772273588.443817   10408 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# “The hybrid embedding + explainability memory outperforms single-modality memory, indicating that semantic and gradient-level similarity capture complementary attack signatures.”
